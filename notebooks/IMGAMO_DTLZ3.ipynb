# %%
import sys
sys.path.append('../pyorderedfuzzy')
sys.path.append('../pyimgamo')

# %%
import numpy as np
import imgamo
import problems
from problems import Kursawe, Problem, DTLZ3, DTLZ2
from players import ClonalSelection, SimulatedAnnealing, SimpleGeneticAlg, ScipyMinimize
from operators import hiper_mutate
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
nobjs = 3
nvars = 7
#problem = DTLZ2(nobjs=nobjs, nvars=9, need_repair=False)
problem = DTLZ3(nobjs=nobjs, nvars=nvars, need_repair=False)

# %%
players = [ClonalSelection(i, nclone=15, supp_level=0, mutate=hiper_mutate, mutate_args=(0.45, 0.9, 0.0001))
           for i in range(nobjs)]
#players = [ScipyMinimize(i, niter=1) for i in range(nobjs)]

# %%
options = imgamo.Options(population_size=25, max_evaluations=-1, max_iterations=1000, exchange_iter=3, change_iter=3,
                         front_max=200, seed=None, verbose=100)

# %%
solver = imgamo.IMGAMO(problem, players, options)

# %%
solver.run_algorithm()
# Out:
# Iteration:  100
# Evaluation count:  [35269. 35269. 35269.]
# Front size:  35
# Elapsed time: 0.27738519700000097
#
# Iteration:  200
# Evaluation count:  [69854. 69854. 69854.]
# Front size:  200
# Elapsed time: 1.0213894689999847
#
# Iteration:  300
# Evaluation count:  [102756. 102756. 102756.]
# Front size:  200
# Elapsed time: 2.4782583880000004
#
# Iteration:  400
# Evaluation count:  [138055. 138055. 138055.]
# Front size:  200
# Elapsed time: 3.941103709999993
#
# Iteration:  500
# Evaluation count:  [170918. 170918. 170918.]
# Front size:  200
# Elapsed time: 5.348208470999992
#
# Iteration:  600
# Evaluation count:  [206760. 206760. 206760.]
# Front size:  200
# Elapsed time: 6.931947690999976
#
# Iteration:  700
# Evaluation count:  [242422. 242422. 242422.]
# Front size:  200
# Elapsed time: 8.536341126999986
#
# Iteration:  800
# Evaluation count:  [277514. 277514. 277514.]
# Front size:  200
# Elapsed time: 9.963880536999994
#
# Iteration:  900
# Evaluation count:  [312639. 312639. 312639.]
# Front size:  200
# Elapsed time: 11.751047202999985
#
# Iteration:  1000
# Evaluation count:  [346087. 346087. 346087.]
# Front size:  200
# Elapsed time: 13.83535508
#
# Iteration:  1000
# Evaluation count:  [346087. 346087. 346087.]
# Front size:  200
# Elapsed time: 13.836392598999993

# %%
solver.result.summary()
# Out:
# Iterations:  1000
# Evaluation count:  [346087. 346087. 346087.]
# Evaluation count per iteration:  [346.087 346.087 346.087]
# Front size:  200
# Time: 13.865209538999977
# Time per iteration: 0.013865209538999976

# %%
# %matplotlib notebook
ax = plt.figure().add_subplot(111, projection='3d')
solver.result.plot_3d(ax, 0, 1, 2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.power(0.1/5, 1/1000)
# Out:
# 0.9960956189881034

# %%
players = [SimulatedAnnealing(i, temp=1000, dec_step=0.996, mutate=hiper_mutate, mutate_args=(0.45, 0.9, 0.1))
           for i in range(nobjs)]
options = imgamo.Options(population_size=25, max_evaluations=-1, max_iterations=1000, exchange_iter=3, change_iter=3,
                         front_max=200, seed=None, verbose=100)

# %%
solver = imgamo.IMGAMO(problem, players, options)

# %%
solver.run_algorithm()
# Out:
# Iteration:  100
# Evaluation count:  [17650. 17650. 17650.]
# Front size:  200
# Elapsed time: 1.2216483640000035
#
# Iteration:  200
# Evaluation count:  [35075. 35075. 35075.]
# Front size:  200
# Elapsed time: 2.5336091739999915
#
# Iteration:  300
# Evaluation count:  [52725. 52725. 52725.]
# Front size:  200
# Elapsed time: 3.9080230470000004
#
# Iteration:  400
# Evaluation count:  [70150. 70150. 70150.]
# Front size:  200
# Elapsed time: 5.247185769999987
#
# Iteration:  500
# Evaluation count:  [87575. 87575. 87575.]
# Front size:  200
# Elapsed time: 6.538459889999984
#
# Iteration:  600
# Evaluation count:  [105225. 105225. 105225.]
# Front size:  200
# Elapsed time: 7.778616613999986
#
# Iteration:  700
# Evaluation count:  [122650. 122650. 122650.]
# Front size:  200
# Elapsed time: 9.13191867399999
#
# Iteration:  800
# Evaluation count:  [140075. 140075. 140075.]
# Front size:  200
# Elapsed time: 10.389844229999994
#
# Iteration:  900
# Evaluation count:  [157725. 157725. 157725.]
# Front size:  200
# Elapsed time: 11.692219139000002
#
# Iteration:  1000
# Evaluation count:  [175150. 175150. 175150.]
# Front size:  200
# Elapsed time: 13.023561790999992
#
# Iteration:  1000
# Evaluation count:  [175150. 175150. 175150.]
# Front size:  200
# Elapsed time: 13.02421841200001

# %%
solver.result.summary()
# Out:
# Iterations:  1000
# Evaluation count:  [175150. 175150. 175150.]
# Evaluation count per iteration:  [175.15 175.15 175.15]
# Front size:  200
# Time: 13.052816869999987
# Time per iteration: 0.013052816869999987

# %%
# %matplotlib notebook
ax = plt.figure().add_subplot(111, projection='3d')
solver.result.plot_3d(ax, 0, 1, 2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
players = [SimpleGeneticAlg(i, pc=0.7, pm=0.05, dx=0.001) for i in range(nobjs)]
options = imgamo.Options(population_size=25, max_evaluations=-1, max_iterations=3000, exchange_iter=3, change_iter=3,
                         front_max=200, seed=None, verbose=100)

# %%
solver = imgamo.IMGAMO(problem, players, options)

# %%
solver.run_algorithm()
# Out:
# Iteration:  100
# Evaluation count:  [8400. 8400.]
# Front size:  30
# Elapsed time: 0.1709559269999943
#
# Iteration:  200
# Evaluation count:  [16700. 16700.]
# Front size:  51
# Elapsed time: 0.3294445479999979
#
# Iteration:  300
# Evaluation count:  [25100. 25100.]
# Front size:  94
# Elapsed time: 0.5191202970000006
#
# Iteration:  400
# Evaluation count:  [33400. 33400.]
# Front size:  88
# Elapsed time: 0.707008314999996
#
# Iteration:  500
# Evaluation count:  [41700. 41700.]
# Front size:  88
# Elapsed time: 0.8959374749999967
#
# Iteration:  600
# Evaluation count:  [50100. 50100.]
# Front size:  126
# Elapsed time: 1.0930354030000018
#
# Iteration:  700
# Evaluation count:  [58400. 58400.]
# Front size:  134
# Elapsed time: 1.320249001999997
#
# Iteration:  800
# Evaluation count:  [66700. 66700.]
# Front size:  164
# Elapsed time: 1.5746068539999953
#
# Iteration:  900
# Evaluation count:  [75100. 75100.]
# Front size:  161
# Elapsed time: 1.840129724999997
#
# Iteration:  1000
# Evaluation count:  [83400. 83400.]
# Front size:  173
# Elapsed time: 2.126977803999992
#
# Iteration:  1100
# Evaluation count:  [91700. 91700.]
# Front size:  178
# Elapsed time: 2.4146744579999933
#
# Iteration:  1200
# Evaluation count:  [100100. 100100.]
# Front size:  178
# Elapsed time: 2.7218561769999923
#
# Iteration:  1300
# Evaluation count:  [108400. 108400.]
# Front size:  184
# Elapsed time: 3.0333911789999917
#
# Iteration:  1400
# Evaluation count:  [116700. 116700.]
# Front size:  192
# Elapsed time: 3.3510957599999927
#
# Iteration:  1500
# Evaluation count:  [125100. 125100.]
# Front size:  192
# Elapsed time: 3.6567984240000015
#
# Iteration:  1600
# Evaluation count:  [133400. 133400.]
# Front size:  193
# Elapsed time: 3.9584599389999937
#
# Iteration:  1700
# Evaluation count:  [141700. 141700.]
# Front size:  196
# Elapsed time: 4.279611459999998
#
# Iteration:  1800
# Evaluation count:  [150100. 150100.]
# Front size:  198
# Elapsed time: 4.593129208999997
#
# Iteration:  1900
# Evaluation count:  [158400. 158400.]
# Front size:  200
# Elapsed time: 4.914078809000003
#
# Iteration:  2000
# Evaluation count:  [166700. 166700.]
# Front size:  200
# Elapsed time: 5.256794902999999
#
# Iteration:  2100
# Evaluation count:  [175100. 175100.]
# Front size:  200
# Elapsed time: 5.679642490999996
#
# Iteration:  2200
# Evaluation count:  [183400. 183400.]
# Front size:  200
# Elapsed time: 6.003895157999992
#
# Iteration:  2300
# Evaluation count:  [191700. 191700.]
# Front size:  198
# Elapsed time: 6.308763830000004
#
# Iteration:  2400
# Evaluation count:  [200100. 200100.]
# Front size:  199
# Elapsed time: 6.659076988999999
#
# Iteration:  2500
# Evaluation count:  [208400. 208400.]
# Front size:  198
# Elapsed time: 6.968434525999996
#
# Iteration:  2600
# Evaluation count:  [216700. 216700.]
# Front size:  200
# Elapsed time: 7.317201908000001
#
# Iteration:  2700
# Evaluation count:  [225100. 225100.]
# Front size:  200
# Elapsed time: 7.664199194000005
#
# Iteration:  2800
# Evaluation count:  [233400. 233400.]
# Front size:  199
# Elapsed time: 7.974334576000004
#
# Iteration:  2900
# Evaluation count:  [241700. 241700.]
# Front size:  200
# Elapsed time: 8.311796314000006
#
# Iteration:  3000
# Evaluation count:  [250000. 250000.]
# Front size:  200
# Elapsed time: 8.73745873
#
# Iteration:  3000
# Evaluation count:  [250000. 250000.]
# Front size:  200
# Elapsed time: 8.737874312000002

# %%
solver.result.summary()
# Out:
# Iterations:  3000
# Evaluation count:  [250000. 250000.]
# Evaluation count per iteration:  [83.33333333 83.33333333]
# Front size:  200
# Time: 8.757874450999992
# Time per iteration: 0.002919291483666664

# %%
fig, ax = plt.subplots()
solver.result.plot_2d(ax, 0, 1)
plt.show()
